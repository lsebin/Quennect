# %%
import pandas as pd
import numpy as np
from datetime import datetime
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %cd ..
# Out:
# c:\Users\celin\git\Quennect

# %%
df = pd.read_csv('q_total.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6740 entries, 0 to 6739
# Data columns (total 88 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Unnamed: 0.1                      6740 non-null   int64
#  1   Unnamed: 0                        6740 non-null   int64
#  2   q_date                            6740 non-null   object
#  3   q_year                            6740 non-null   float64
#  4   prop_year                         6740 non-null   float64
#  5   state                             6740 non-null   object
#  6   entity                            6740 non-null   object
#  7   utility                           6740 non-null   object
#  8   county_1                          6740 non-null   object
#  9   poi_name                          6740 non-null   object
#  10  region_CAISO                      6740 non-null   int64
# ...

# %%
dup = df.duplicated(subset=['Lat', 'Long'], keep=False)
dup= df[mismatched == True]
dup.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0      q_date  q_year  prop_year state entity
# 0             0           0    1/7/2022  2022.0     2024.0    MO    AEC  \
# 1             1           3  11/19/2018  2018.0     2021.0    MO    AEC
# 2             2           6  10/12/2017  2017.0     2020.0    MO    AEC
# 3             3           9   12/6/2018  2018.0     2021.0    MO    AEC
# 5             5          20    3/6/2019  2019.0     2019.0    MO    AEC
#
#   utility    county_1                    poi_name  ...  GEOID  votes_dem
# 0     AEC  new madrid    New Madrid - Essex 345kV  ...    NaN        NaN  \
# 1     AEC    pemiscot   New Madrid to Dell 500 kV  ...    NaN        NaN
# 2     AEC  new madrid       New Madrid Substation  ...    NaN        NaN
# 3     AEC  new madrid  New Madrid to Essex 345 kV  ...    NaN        NaN
# 5     AEC     dunklin          St. Francis 161 kV  ...    NaN        NaN
#
#    votes_rep  votes_total  votes_per_sqkm  pct_dem_lead  solar_ann_ghi_rn
# ...

# %%
cols = list(df.columns)
